# %%
import struct
import numpy as np
import math

def read_DCD_Header(file):
    struct.unpack('i', file.read(4))
    struct.unpack('ssss', file.read(4))
    nFrames = struct.unpack('i', file.read(4))[0]
    t0 = struct.unpack('i', file.read(4))[0]
    dt = struct.unpack('i', file.read(4))[0]
    
    #Dummy variables
    for i in range(6):
        struct.unpack('i', file.read(4))
    struct.unpack('f', file.read(4))
    for i in range(10):
        struct.unpack('i', file.read(4))
    struct.unpack('i', file.read(4))
    
    titleLength = int(struct.unpack('i', file.read(4))[0])
    title = struct.unpack(f'{titleLength}s', file.read(titleLength))
    
    #Dummies
    struct.unpack('i', file.read(4))
    struct.unpack('i', file.read(4))
   
    nAtoms = int(struct.unpack('i', file.read(4))[0])
    struct.unpack('i', file.read(4))
    
    print(f"Reading trajectory with {nFrames} frames and {nAtoms} atoms")
    return nFrames, nAtoms

def read_DCD_Coords(file, frame):
    print("Reading trajectory frame %d" % frame)
    struct.unpack('i', file.read(4))
    struct.unpack('d'*6, file.read(8*6))
    struct.unpack('i'*2, file.read(4*2))
    for i in range(nAtoms):
        arr[i,0]=struct.unpack('f', file.read(4))[0]
    struct.unpack('i', file.read(4))
    struct.unpack('i', file.read(4))

    for i in range(nAtoms):
        arr[i,1]=struct.unpack('f', file.read(4))[0]
    struct.unpack('i', file.read(4))
    struct.unpack('i', file.read(4))

    for i in range(nAtoms):
        arr[i,2]=struct.unpack('f', file.read(4))[0]

    struct.unpack('i', file.read(4))
    return arr

def compute_distance(coord1, coord2):
    return np.sqrt((coord1[0]-coord2[0])**2 + (coord1[1]-coord2[1])**2 + (coord1[2]-coord2[2])**2)

def compute_inverse_distance(coord1, coord2):
    tmp = compute_distance(coord1, coord2)
    if tmp != 0:
        return 1/tmp
    else:
        return -1
    
def main(fileName, sel1, sel2):
    with open(fileName, mode='rb') as trajectory: #b is important -> binary
        nFrames, nAtoms = read_DCD_Header(trajectory)
        coords = np.zeros((nFrames, nAtoms, 3))
        distance_matrix = np.zeros((nFrames, len(sel1), len(sel2)))
        for j in range(nFrames):
            coords[j] = read_DCD_Coords(trajectory, j)
            dist = [(a[0] - b[0])**2 + (a[1] - b[1])**2 + (a[2] - b[2])**2 for a, b in zip(coords[j,sel1], coords[j,sel2])]
            dist = math.sqrt(sum(dist))
            print(np.shape(dist))
        
            #for s1 in range(len(sel1)):
            #    for s2 in range(len(sel2)):
            #        distance_matrix[j,s1,s2] = compute_inverse_distance(coords[j,sel1[s1]],coords[j,sel2[s2]])

# %%
sel1 = np.arange(0,50,1)
sel2 = np.arange(50,100,1)
main("../practice.dcd", sel1, sel2)
# Out:
# Reading trajectory with 3995 frames and 1435 atoms
# Reading trajectory frame 0
# ()
# Reading trajectory frame 1
# ()
# Reading trajectory frame 2
# ()
# Reading trajectory frame 3
# ()
# Reading trajectory frame 4
# ()
# Reading trajectory frame 5
# ()
# Reading trajectory frame 6
# ()
# Reading trajectory frame 7
# ()
# Reading trajectory frame 8
# ()
# Reading trajectory frame 9
# ()
# Reading trajectory frame 10
# ()
# Reading trajectory frame 11
# ()
# Reading trajectory frame 12
# ()
# Reading trajectory frame 13
# ()
# Reading trajectory frame 14
# ()
# Reading trajectory frame 15
# ()
# Reading trajectory frame 16
# ()
# Reading trajectory frame 17
# ()
# Reading trajectory frame 18
# ()
# Reading trajectory frame 19
# ()
# Reading trajectory frame 20
# ()
# Reading trajectory frame 21
# ()
# Reading trajectory frame 22
# ()
# Reading trajectory frame 23
# ()
# Reading trajectory frame 24
# ()
# Reading trajectory frame 25
# ()
# Reading trajectory frame 26
# ()
# Reading trajectory frame 27
# ()
# Reading trajectory frame 28
# ()
# Reading trajectory frame 29
# ()
# Reading trajectory frame 30
# ()
# Reading trajectory frame 31
# ()
# Reading trajectory frame 32
# ()
# Reading trajectory frame 33
# ()
# Reading trajectory frame 34
# ()
# Reading trajectory frame 35
# ()
# Reading trajectory frame 36
# ()
# Reading trajectory frame 37
# ()
# Reading trajectory frame 38
# ()
# Reading trajectory frame 39
# ()
# Reading trajectory frame 40
# ()
# Reading trajectory frame 41
# ()
# Reading trajectory frame 42
# ()
# Reading trajectory frame 43
# ()
# Reading trajectory frame 44
# ()
# Reading trajectory frame 45
# ()
# Reading trajectory frame 46
# ()
# Reading trajectory frame 47
# ()
# Reading trajectory frame 48
# ()
# Reading trajectory frame 49
# ()
# Reading trajectory frame 50
# ()
# Reading trajectory frame 51
# ()
# Reading trajectory frame 52
# ()
# Reading trajectory frame 53
# ()
# Reading trajectory frame 54
# ()
# Reading trajectory frame 55
# ()
# Reading trajectory frame 56
# ()
# Reading trajectory frame 57
# ()
# Reading trajectory frame 58
# ()
# Reading trajectory frame 59
# ()
# Reading trajectory frame 60
# ()
# Reading trajectory frame 61
# ()
# Reading trajectory frame 62
# ()
# Reading trajectory frame 63
# ()
# Reading trajectory frame 64
# ()
# Reading trajectory frame 65
# ()
# Reading trajectory frame 66
# ()
# Reading trajectory frame 67
# ()
# Reading trajectory frame 68
# ()
# Reading trajectory frame 69
# ()
# Reading trajectory frame 70
# ()
# Reading trajectory frame 71
# ()
# Reading trajectory frame 72
# ()
# Reading trajectory frame 73
# ()
# Reading trajectory frame 74
# ()
# Reading trajectory frame 75
# ()
# Reading trajectory frame 76
# ()
# Reading trajectory frame 77
# ()
# Reading trajectory frame 78
# ()
# Reading trajectory frame 79
# ()
# Reading trajectory frame 80
# ()
# Reading trajectory frame 81
# ()
# Reading trajectory frame 82
# ()
# Reading trajectory frame 83
# ()
# Reading trajectory frame 84
# ()
# Reading trajectory frame 85
# ()
# Reading trajectory frame 86
# ()
# Reading trajectory frame 87
# ()
# Reading trajectory frame 88
# ()
# Reading trajectory frame 89
# ()
# Reading trajectory frame 90
# ()
# Reading trajectory frame 91
# ()
# Reading trajectory frame 92
# ()
# Reading trajectory frame 93
# ()
# Reading trajectory frame 94
# ()
# Reading trajectory frame 95
# ()
# Reading trajectory frame 96
# ()
# Reading trajectory frame 97
# ()
# Reading trajectory frame 98
# ()
# Reading trajectory frame 99
# ()
# Reading trajectory frame 100
# ()
# Reading trajectory frame 101
# ()
# Reading trajectory frame 102
# ()
# Reading trajectory frame 103
# ()
# Reading trajectory frame 104
# ()
# Reading trajectory frame 105
# ()
# Reading trajectory frame 106
# ()
# Reading trajectory frame 107
# ()
# Reading trajectory frame 108
# ()
# Reading trajectory frame 109
# ()
# Reading trajectory frame 110
# ()
# Reading trajectory frame 111
# ()
# Reading trajectory frame 112
# ()
# Reading trajectory frame 113
# ()
# Reading trajectory frame 114
# ()
# Reading trajectory frame 115
# ()
# Reading trajectory frame 116
# ()
# Reading trajectory frame 117
# ()
# Reading trajectory frame 118
# ()
# Reading trajectory frame 119
# ()
# Reading trajectory frame 120
# ()
# Reading trajectory frame 121
# ()
# Reading trajectory frame 122
# ()
# Reading trajectory frame 123
# ()
# Reading trajectory frame 124
# ()
# Reading trajectory frame 125
# ()
# Reading trajectory frame 126
# ()
# Reading trajectory frame 127
# ()
# Reading trajectory frame 128
# ()
# Reading trajectory frame 129
# ()
# Reading trajectory frame 130
# ()
# Reading trajectory frame 131
# ()
# Reading trajectory frame 132
# ()
# Reading trajectory frame 133
# ()
# Reading trajectory frame 134
# ()
# Reading trajectory frame 135
# ()
# Reading trajectory frame 136
# ()
# Reading trajectory frame 137
# ()
# Reading trajectory frame 138
# ()
# Reading trajectory frame 139
# ()
# Reading trajectory frame 140
# ()
# Reading trajectory frame 141
# ()
# Reading trajectory frame 142
# ()
# Reading trajectory frame 143
# ()
# Reading trajectory frame 144
# ()
# Reading trajectory frame 145
# ()
# Reading trajectory frame 146
# ()
# Reading trajectory frame 147
# ()
# Reading trajectory frame 148
# ()
# Reading trajectory frame 149
# ()
# Reading trajectory frame 150
# ()
# Reading trajectory frame 151
# ()
# Reading trajectory frame 152
# ()
# Reading trajectory frame 153
# ()
# Reading trajectory frame 154
# ()
# Reading trajectory frame 155
# ()
# Reading trajectory frame 156
# ()
# Reading trajectory frame 157
# ()
# Reading trajectory frame 158
# ()
# Reading trajectory frame 159
# ()
# Reading trajectory frame 160
# ()
# Reading trajectory frame 161
# ()
# Reading trajectory frame 162
# ()
# Reading trajectory frame 163
# ()
# Reading trajectory frame 164
# ()
# Reading trajectory frame 165
# ()
# Reading trajectory frame 166
# ()
# Reading trajectory frame 167
# ()
# Reading trajectory frame 168
# ()
# Reading trajectory frame 169
# ()
# Reading trajectory frame 170
# ()
# Reading trajectory frame 171
# ()
# Reading trajectory frame 172
# ()
# Reading trajectory frame 173
# ()
# Reading trajectory frame 174
# ()
# Reading trajectory frame 175
# ()
# Reading trajectory frame 176
# ()
# Reading trajectory frame 177
# ()
# Reading trajectory frame 178
# ()
# Reading trajectory frame 179
# ()
# Reading trajectory frame 180
# ()
# Reading trajectory frame 181
# ()
# Reading trajectory frame 182
# ()
# Reading trajectory frame 183
# ()
# Reading trajectory frame 184
# ()
# Reading trajectory frame 185
# ()
# Reading trajectory frame 186
# ()
# Reading trajectory frame 187
# ()
# Reading trajectory frame 188
# ()
# Reading trajectory frame 189
# ()
# Reading trajectory frame 190
# ()
# Reading trajectory frame 191
# ()
# Reading trajectory frame 192
# ()
# Reading trajectory frame 193
# ()
# Reading trajectory frame 194
# ()
# Reading trajectory frame 195
# ()
# Reading trajectory frame 196
# ()
# Reading trajectory frame 197
# ()
# Reading trajectory frame 198
# ()
# Reading trajectory frame 199
# ()
# Reading trajectory frame 200
# ()
# Reading trajectory frame 201
# ()
# Reading trajectory frame 202
# ()
# Reading trajectory frame 203
# ()
# Reading trajectory frame 204
# ()
# Reading trajectory frame 205
# ()
# Reading trajectory frame 206
# ()
# Reading trajectory frame 207
# ()
# Reading trajectory frame 208
# ()
# Reading trajectory frame 209
# ()
# Reading trajectory frame 210
# ()
# Reading trajectory frame 211
# ()
# Reading trajectory frame 212
# ()
# Reading trajectory frame 213
# ()
# Reading trajectory frame 214
# ()
# Reading trajectory frame 215
# ()
# Reading trajectory frame 216
# ()
# Reading trajectory frame 217
# ()
# Reading trajectory frame 218
# ()
# Reading trajectory frame 219
# ()
# Reading trajectory frame 220
# ()
# Reading trajectory frame 221
# ()
# Reading trajectory frame 222
# ()
# Reading trajectory frame 223
# ()
# Reading trajectory frame 224
# ()
# Reading trajectory frame 225
# ()
# Reading trajectory frame 226
# ()
# Reading trajectory frame 227
# ()
# Reading trajectory frame 228
# ()
# Reading trajectory frame 229
# ()
# Reading trajectory frame 230
# ()
# Reading trajectory frame 231
# ()
# Reading trajectory frame 232
# ()
# Reading trajectory frame 233
# ()
# Reading trajectory frame 234
# ()
# Reading trajectory frame 235
# ()
# Reading trajectory frame 236
# ()
# Reading trajectory frame 237
# ()
# Reading trajectory frame 238
# ()
# Reading trajectory frame 239
# ()
# Reading trajectory frame 240
# ()
# Reading trajectory frame 241
# ()
# Reading trajectory frame 242
# ()
# Reading trajectory frame 243
# ()
# Reading trajectory frame 244
# ()
# Reading trajectory frame 245
# ()
# Reading trajectory frame 246
# ()
# Reading trajectory frame 247
# ()
# Reading trajectory frame 248
# ()
# Reading trajectory frame 249
# ()
# Reading trajectory frame 250
# ()
# Reading trajectory frame 251
# ()
# Reading trajectory frame 252
# ()
# Reading trajectory frame 253
# ()
# Reading trajectory frame 254
# ()
# Reading trajectory frame 255
# ()
# Reading trajectory frame 256
# ()
# Reading trajectory frame 257
# ()
# Reading trajectory frame 258
# ()
# Reading trajectory frame 259
# ()
# Reading trajectory frame 260
# ()
# Reading trajectory frame 261
# ()
# Reading trajectory frame 262
# ()
# Reading trajectory frame 263
# ()
# Reading trajectory frame 264
# ()
# Reading trajectory frame 265
# ()
# Reading trajectory frame 266
# ()
# Reading trajectory frame 267
# ()
# Reading trajectory frame 268
# ()
# Reading trajectory frame 269
# ()
# Reading trajectory frame 270
# ()
# Reading trajectory frame 271
# ()
# Reading trajectory frame 272
# ()
# Reading trajectory frame 273
# ()
# Reading trajectory frame 274
# ()
# Reading trajectory frame 275
# ()
# Reading trajectory frame 276
# ()
# Reading trajectory frame 277
# ()
# Reading trajectory frame 278
# ()
# Reading trajectory frame 279
# ()
# Reading trajectory frame 280
# ()
# Reading trajectory frame 281
# ()
# Reading trajectory frame 282
# ()
# Reading trajectory frame 283
# ()
# Reading trajectory frame 284
# ()
# Reading trajectory frame 285
# ()
# Reading trajectory frame 286
# ()
# Reading trajectory frame 287
# ()
# Reading trajectory frame 288
# ()
# Reading trajectory frame 289
# ()
# Reading trajectory frame 290
# ()
# Reading trajectory frame 291
# ()
# Reading trajectory frame 292
# ()
# Reading trajectory frame 293
# ()
# Reading trajectory frame 294
# ()
# Reading trajectory frame 295
# ()
# Reading trajectory frame 296
# ()
# Reading trajectory frame 297
# ()
# Reading trajectory frame 298
# ()
# Reading trajectory frame 299
# ()
# Reading trajectory frame 300
# ()
# Reading trajectory frame 301
# ()
# Reading trajectory frame 302
# ()
# Reading trajectory frame 303
# ()
# Reading trajectory frame 304
# ()
# Reading trajectory frame 305
# ()
# Reading trajectory frame 306
# ()
# Reading trajectory frame 307
# ()
# Reading trajectory frame 308
# ()
# Reading trajectory frame 309
# ()
# Reading trajectory frame 310
# ()
# Reading trajectory frame 311
# ()
# Reading trajectory frame 312
# ()
# Reading trajectory frame 313
# ()
# Reading trajectory frame 314
# ()
# Reading trajectory frame 315
# ()
# Reading trajectory frame 316
# ()
# Reading trajectory frame 317
# ()
# Reading trajectory frame 318
# ()
# Reading trajectory frame 319
# ()
# Reading trajectory frame 320
# ()
# Reading trajectory frame 321
# ()
# Reading trajectory frame 322
# ()
# Reading trajectory frame 323
# ()
# Reading trajectory frame 324
# ()
# Reading trajectory frame 325
# ()
# Reading trajectory frame 326
# ()
# Reading trajectory frame 327
# ()
# Reading trajectory frame 328
# ()
# Reading trajectory frame 329
# ()
# Reading trajectory frame 330
# ()
# Reading trajectory frame 331
# ()
# Reading trajectory frame 332
# ()
# Reading trajectory frame 333
# ()
# Reading trajectory frame 334
# ()
# Reading trajectory frame 335
# ()
# Reading trajectory frame 336
# ()
# Reading trajectory frame 337
# ()
# Reading trajectory frame 338
# ()
# Reading trajectory frame 339
# ()
# Reading trajectory frame 340
# ()
# Reading trajectory frame 341
# ()
# Reading trajectory frame 342
# ()
# Reading trajectory frame 343
# ()
# Reading trajectory frame 344
# ()
# Reading trajectory frame 345
# ()
# Reading trajectory frame 346
# ()
# Reading trajectory frame 347
# ()
# Reading trajectory frame 348
# ()
# Reading trajectory frame 349
# ()
# Reading trajectory frame 350
# ()
# Reading trajectory frame 351
# ()
# Reading trajectory frame 352
# ()
# Reading trajectory frame 353
# ()
# Reading trajectory frame 354
# ()
# Reading trajectory frame 355
# ()
# Reading trajectory frame 356
# ()
# Reading trajectory frame 357
# ()
# Reading trajectory frame 358
# ()
# Reading trajectory frame 359
# ()
# Reading trajectory frame 360
# ()
# Reading trajectory frame 361
# ()
# Reading trajectory frame 362
# ()
# Reading trajectory frame 363
# ()
# Reading trajectory frame 364
# ()
# Reading trajectory frame 365
# ()
# Reading trajectory frame 366
# ()
# Reading trajectory frame 367
# ()
# Reading trajectory frame 368
# ()
# Reading trajectory frame 369
# ()
# Reading trajectory frame 370
# ()
# Reading trajectory frame 371
# ()
# Reading trajectory frame 372
# ()
# Reading trajectory frame 373
# ()
# Reading trajectory frame 374
# ()
# Reading trajectory frame 375
# ()
# Reading trajectory frame 376
# ()
# Reading trajectory frame 377
# ()
# Reading trajectory frame 378
# ()
# Reading trajectory frame 379
# ()
# Reading trajectory frame 380
# ()
# Reading trajectory frame 381
# ()
# Reading trajectory frame 382
# ()
# Reading trajectory frame 383
# ()
# Reading trajectory frame 384
# ()
# Reading trajectory frame 385
# ()
# Reading trajectory frame 386
# ()
# Reading trajectory frame 387
# ()
# Reading trajectory frame 388
# ()
# Reading trajectory frame 389
# ()
# Reading trajectory frame 390
# ()
# Reading trajectory frame 391
# ()
# Reading trajectory frame 392
# ()
# Reading trajectory frame 393
# ()
# Reading trajectory frame 394
# ()
# Reading trajectory frame 395
# ()
# Reading trajectory frame 396
# ()
# Reading trajectory frame 397
# ()
# Reading trajectory frame 398
# ()
# Reading trajectory frame 399
# ()
# Reading trajectory frame 400
# ()
# Reading trajectory frame 401
# ()
# Reading trajectory frame 402
# ()
# Reading trajectory frame 403
# ()
# Reading trajectory frame 404
# ()
# Reading trajectory frame 405
# ()
# Reading trajectory frame 406
# ()
# Reading trajectory frame 407
# ()
# Reading trajectory frame 408
# ()
# Reading trajectory frame 409
# ()
# Reading trajectory frame 410
# ()
# Reading trajectory frame 411
# ()
# Reading trajectory frame 412
# ()
# Reading trajectory frame 413
# ()
# Reading trajectory frame 414
# ()
# Reading trajectory frame 415
# ()
# Reading trajectory frame 416
# ()
# Reading trajectory frame 417
# ()
# Reading trajectory frame 418
# ()
# Reading trajectory frame 419
# ()
# Reading trajectory frame 420
# ()
# Reading trajectory frame 421
# ()
# Reading trajectory frame 422
# ()
# Reading trajectory frame 423
# ()
# Reading trajectory frame 424
# ()
# Reading trajectory frame 425
# ()
# Reading trajectory frame 426
# ()
# Reading trajectory frame 427
# ()
# Reading trajectory frame 428
# ()
# Reading trajectory frame 429
# ()
# Reading trajectory frame 430
# ()
# Reading trajectory frame 431
# ()
# Reading trajectory frame 432
# ()
# Reading trajectory frame 433
# ()
# Reading trajectory frame 434
# ()
# Reading trajectory frame 435
# ()
# Reading trajectory frame 436
# ()
# Reading trajectory frame 437
# ()
# Reading trajectory frame 438
# ()
# Reading trajectory frame 439
# ()
# Reading trajectory frame 440
# ()
# Reading trajectory frame 441
# ()
# Reading trajectory frame 442
# ()
# Reading trajectory frame 443
# ()
# Reading trajectory frame 444
# ()
# Reading trajectory frame 445
# ()
# Reading trajectory frame 446
# ()
# Reading trajectory frame 447
# ()
# Reading trajectory frame 448
# ()
# Reading trajectory frame 449
# ()
# Reading trajectory frame 450
# ()
# Reading trajectory frame 451
# ()
# Reading trajectory frame 452
# ()
# Reading trajectory frame 453
# ()
# Reading trajectory frame 454
# ()
# Reading trajectory frame 455
# ()
# Reading trajectory frame 456
# ()
# Reading trajectory frame 457
# ()
# Reading trajectory frame 458
# ()
# Reading trajectory frame 459
# ()
# Reading trajectory frame 460
# ()
# Reading trajectory frame 461
# ()
# Reading trajectory frame 462
# ()
# Reading trajectory frame 463
# ()
# Reading trajectory frame 464
# ()
# Reading trajectory frame 465
# ()
# Reading trajectory frame 466
# ()
# Reading trajectory frame 467
# ()
# Reading trajectory frame 468
# ()
# Reading trajectory frame 469
# ()
# Reading trajectory frame 470
# ()
# Reading trajectory frame 471
# ()
# Reading trajectory frame 472
# ()
# Reading trajectory frame 473
# ()
# Reading trajectory frame 474
# ()
# Reading trajectory frame 475
# ()
# Reading trajectory frame 476
# ()
# Reading trajectory frame 477
# ()
# Reading trajectory frame 478
# ()
# Reading trajectory frame 479
# ()
# Reading trajectory frame 480
# ()
# Reading trajectory frame 481
# ()
# Reading trajectory frame 482
# ()
# Reading trajectory frame 483
# ()
# Reading trajectory frame 484
# ()
# Reading trajectory frame 485
# ()
# Reading trajectory frame 486
# ()
# Reading trajectory frame 487
# ()
# Reading trajectory frame 488
# ()
# Reading trajectory frame 489
# ()
# Reading trajectory frame 490
# ()
# Reading trajectory frame 491
# ()
# Reading trajectory frame 492
# ()
# Reading trajectory frame 493
# ()
# Reading trajectory frame 494
# ()
# Reading trajectory frame 495
# ()
# Reading trajectory frame 496
# ()
# Reading trajectory frame 497
# ()
# Reading trajectory frame 498
# ()
# Reading trajectory frame 499
# ()
# Reading trajectory frame 500
# ()
# Reading trajectory frame 501
# ()
# Reading trajectory frame 502
# ()
# Reading trajectory frame 503
# ()
# Reading trajectory frame 504
# ()
# Reading trajectory frame 505
# ()
# Reading trajectory frame 506
# ()
# Reading trajectory frame 507
# ()
# Reading trajectory frame 508
# ()
# Reading trajectory frame 509
# ()
# Reading trajectory frame 510
# ()
# Reading trajectory frame 511
# ()
# Reading trajectory frame 512
# ()
# Reading trajectory frame 513
# ()
# Reading trajectory frame 514
# ()
# Reading trajectory frame 515
# ()
# Reading trajectory frame 516
# ()
# Reading trajectory frame 517
# ()
# Reading trajectory frame 518
# ()
# Reading trajectory frame 519
# ()
# Reading trajectory frame 520
# ()
# Reading trajectory frame 521
# ()
# Reading trajectory frame 522
# ()
# Reading trajectory frame 523
# ()
# Reading trajectory frame 524
# ()
# Reading trajectory frame 525
# ()
# Reading trajectory frame 526
# ()
# Reading trajectory frame 527
# ()
# Reading trajectory frame 528
# ()
# Reading trajectory frame 529
# ()
# Reading trajectory frame 530
# ()
# Reading trajectory frame 531
# ()
# Reading trajectory frame 532
# ()
# Reading trajectory frame 533
# ()
# Reading trajectory frame 534
# ()
# Reading trajectory frame 535
# ()
# Reading trajectory frame 536
# ()
# Reading trajectory frame 537
# ()
# Reading trajectory frame 538
# ()
# Reading trajectory frame 539
# ()
# Reading trajectory frame 540
# ()
# Reading trajectory frame 541
# ()
# Reading trajectory frame 542
# ()
# Reading trajectory frame 543
# ()
# Reading trajectory frame 544
# ()
# Reading trajectory frame 545
# ()
# Reading trajectory frame 546
# ()
# Reading trajectory frame 547
# ()
# Reading trajectory frame 548
# ()
# Reading trajectory frame 549
# ()
# Reading trajectory frame 550
# ()
# Reading trajectory frame 551
# ()
# Reading trajectory frame 552
# ()
# Reading trajectory frame 553
# ()
# Reading trajectory frame 554
# ()
# Reading trajectory frame 555
# ()
# Reading trajectory frame 556
# ()
# Reading trajectory frame 557
# ()
# Reading trajectory frame 558
# ()
# Reading trajectory frame 559
# ()
# Reading trajectory frame 560
# ()
# Reading trajectory frame 561
# ()
# Reading trajectory frame 562
# ()
# Reading trajectory frame 563
# ()
# Reading trajectory frame 564
# ()
# Reading trajectory frame 565
# ()
# Reading trajectory frame 566
# ()
# Reading trajectory frame 567
# ()
# Reading trajectory frame 568
# ()
# Reading trajectory frame 569
# ()
# Reading trajectory frame 570
# ()
# Reading trajectory frame 571
# ()
# Reading trajectory frame 572
# ()
# Reading trajectory frame 573
# ()
# Reading trajectory frame 574
# ()
# Reading trajectory frame 575
# ()
# Reading trajectory frame 576
# ()
# Reading trajectory frame 577
# ()
# Reading trajectory frame 578
# ()
# Reading trajectory frame 579
# ()
# Reading trajectory frame 580
# ()
# Reading trajectory frame 581
# ()
# Reading trajectory frame 582
# ()
# Reading trajectory frame 583
# ()
# Reading trajectory frame 584
# ()
# Reading trajectory frame 585
# ()
# Reading trajectory frame 586
# ()
# Reading trajectory frame 587
# ()
# Reading trajectory frame 588
# ()
# Reading trajectory frame 589
# ()
# Reading trajectory frame 590
# ()
# Reading trajectory frame 591
# ()
# Reading trajectory frame 592
# ()
# Reading trajectory frame 593
# ()
# Reading trajectory frame 594
# ()
# Reading trajectory frame 595
# ()
# Reading trajectory frame 596
# ()
# Reading trajectory frame 597
# ()
# Reading trajectory frame 598
# ()
# Reading trajectory frame 599
# ()
# Reading trajectory frame 600
# ()
# Reading trajectory frame 601
# ()
# Reading trajectory frame 602
# ()
# Reading trajectory frame 603
# ()
# Reading trajectory frame 604
# ()
# Reading trajectory frame 605
# ()
# Reading trajectory frame 606
# ()
# Reading trajectory frame 607
# ()
# Reading trajectory frame 608
# ()
# Reading trajectory frame 609
# ()
# Reading trajectory frame 610
# ()
# Reading trajectory frame 611
# ()
# Reading trajectory frame 612
# ()
# Reading trajectory frame 613
# ()
# Reading trajectory frame 614
# ()
# Reading trajectory frame 615
# ()
# Reading trajectory frame 616
# ()
# Reading trajectory frame 617
# ()
# Reading trajectory frame 618
# ()
# Reading trajectory frame 619
# ()
# Reading trajectory frame 620
# ()
# Reading trajectory frame 621
# ()
# Reading trajectory frame 622
# ()
# Reading trajectory frame 623
# ()
# Reading trajectory frame 624
# ()
# Reading trajectory frame 625
# ()
# Reading trajectory frame 626
# ()
# Reading trajectory frame 627
# ()
# Reading trajectory frame 628
# ()
# Reading trajectory frame 629
# ()
# Reading trajectory frame 630
# ()
# Reading trajectory frame 631
# ()
# Reading trajectory frame 632
# ()
# Reading trajectory frame 633
# ()
# Reading trajectory frame 634
# ()
# Reading trajectory frame 635
# ()
# Reading trajectory frame 636
# ()
# Reading trajectory frame 637
# ()
# Reading trajectory frame 638
# ()
# Reading trajectory frame 639
# ()
# Reading trajectory frame 640
# ()
# Reading trajectory frame 641
# ()
# Reading trajectory frame 642
# ()
# Reading trajectory frame 643
# ()
# Reading trajectory frame 644
# ()
# Reading trajectory frame 645
# ()
# Reading trajectory frame 646
# ()
# Reading trajectory frame 647
# ()
# Reading trajectory frame 648
# ()
# Reading trajectory frame 649
# ()
# Reading trajectory frame 650
# ()
# Reading trajectory frame 651
# ()
# Reading trajectory frame 652
# ()
# Reading trajectory frame 653
# ()
# Reading trajectory frame 654
# ()
# Reading trajectory frame 655
# ()
# Reading trajectory frame 656
# ()
# Reading trajectory frame 657
# ()
# Reading trajectory frame 658
# ()
# Reading trajectory frame 659
# ()
# Reading trajectory frame 660
# ()
# Reading trajectory frame 661
# ()
# Reading trajectory frame 662
# ()
# Reading trajectory frame 663
# ()
# Reading trajectory frame 664
# ()
# Reading trajectory frame 665
# ()
# Reading trajectory frame 666
# ()
# Reading trajectory frame 667
# ()
# Reading trajectory frame 668
# ()
# Reading trajectory frame 669
# ()
# Reading trajectory frame 670
# ()
# Reading trajectory frame 671
# ()
# Reading trajectory frame 672
# ()
# Reading trajectory frame 673
# ()
# Reading trajectory frame 674
# ()
# Reading trajectory frame 675
# ()
# Reading trajectory frame 676
# ()
# Reading trajectory frame 677
# ()
# Reading trajectory frame 678
# ()
# Reading trajectory frame 679
# ()
# Reading trajectory frame 680
# ()
# Reading trajectory frame 681
# ()
# Reading trajectory frame 682
# ()
# Reading trajectory frame 683
# ()
# Reading trajectory frame 684
# ()
# Reading trajectory frame 685
# ()
# Reading trajectory frame 686
# ()
# Reading trajectory frame 687
# ()
# Reading trajectory frame 688
# ()
# Reading trajectory frame 689
# ()
# Reading trajectory frame 690
# ()
# Reading trajectory frame 691
# ()
# Reading trajectory frame 692
# ()
# Reading trajectory frame 693
# ()
# Reading trajectory frame 694
# ()
# Reading trajectory frame 695
# ()
# Reading trajectory frame 696
# ()
# Reading trajectory frame 697
# ()
# Reading trajectory frame 698
# ()
# Reading trajectory frame 699
# ()
# Reading trajectory frame 700
# ()
# Reading trajectory frame 701
# ()
# Reading trajectory frame 702
# ()
# Reading trajectory frame 703
# ()
# Reading trajectory frame 704
# ()
# Reading trajectory frame 705
# ()
# Reading trajectory frame 706
# ()
# Reading trajectory frame 707
# ()
# Reading trajectory frame 708
# ()
# Reading trajectory frame 709
# ()
# Reading trajectory frame 710
# ()
# Reading trajectory frame 711
# ()
# Reading trajectory frame 712
# ()
# Reading trajectory frame 713
# ()
# Reading trajectory frame 714
# ()
# Reading trajectory frame 715
# ()
# Reading trajectory frame 716
# ()
# Reading trajectory frame 717
# ()
# Reading trajectory frame 718
# ()
# Reading trajectory frame 719
# ()
# Reading trajectory frame 720
# ()
# Reading trajectory frame 721
# ()
# Reading trajectory frame 722
# ()
# Reading trajectory frame 723
# ()
# Reading trajectory frame 724
# ()
# Reading trajectory frame 725
# ()
# Reading trajectory frame 726
# ()
# Reading trajectory frame 727
# ()
# Reading trajectory frame 728
# ()
# Reading trajectory frame 729
# ()
# Reading trajectory frame 730
# ()
# Reading trajectory frame 731
# ()
# Reading trajectory frame 732
# ()
# Reading trajectory frame 733
# ()
# Reading trajectory frame 734
# ()
# Reading trajectory frame 735
# ()
# Reading trajectory frame 736
# ()
# Reading trajectory frame 737
# ()
# Reading trajectory frame 738
# ()
# Reading trajectory frame 739
# ()
# Reading trajectory frame 740
# ()
# Reading trajectory frame 741
# ()
# Reading trajectory frame 742
# ()
# Reading trajectory frame 743
# ()
# Reading trajectory frame 744
# ()
# Reading trajectory frame 745
# ()
# Reading trajectory frame 746
# ()
# Reading trajectory frame 747
# ()
# Reading trajectory frame 748
# ()
# Reading trajectory frame 749
# ()
# Reading trajectory frame 750
# ()
# Reading trajectory frame 751
# ()
# Reading trajectory frame 752
# ()
# Reading trajectory frame 753
# ()
# Reading trajectory frame 754
# ()
# Reading trajectory frame 755
# ()
# Reading trajectory frame 756
# ()
# Reading trajectory frame 757
# ()
# Reading trajectory frame 758
# ()
# Reading trajectory frame 759
# ()
# Reading trajectory frame 760
# ()
# Reading trajectory frame 761
# ()
# Reading trajectory frame 762
# ()
# Reading trajectory frame 763
# ()
# Reading trajectory frame 764
# ()
# Reading trajectory frame 765
# ()
# Reading trajectory frame 766
# ()
# Reading trajectory frame 767
# ()
# Reading trajectory frame 768
# ()
# Reading trajectory frame 769
# ()
# Reading trajectory frame 770
# ()
# Reading trajectory frame 771
# ()
# Reading trajectory frame 772
# ()
# Reading trajectory frame 773
# ()
# Reading trajectory frame 774
# ()
# Reading trajectory frame 775
# ()
# Reading trajectory frame 776
# ()
# Reading trajectory frame 777
# ()
# Reading trajectory frame 778
# ()
# Reading trajectory frame 779
# ()
# Reading trajectory frame 780
# ()
# Reading trajectory frame 781
# ()
# Reading trajectory frame 782
# ()
# Reading trajectory frame 783
# ()
# Reading trajectory frame 784
# ()
# Reading trajectory frame 785
# ()
# Reading trajectory frame 786
# ()
# Reading trajectory frame 787
# ()
# Reading trajectory frame 788
# ()
# Reading trajectory frame 789
# ()
# Reading trajectory frame 790
# ()
# Reading trajectory frame 791
# ()
# Reading trajectory frame 792
# ()
# Reading trajectory frame 793
# ()
# Reading trajectory frame 794
# ()
# Reading trajectory frame 795
# ()
# Reading trajectory frame 796
# ()
# Reading trajectory frame 797
# ()
# Reading trajectory frame 798
# ()
# Reading trajectory frame 799
# ()
# Reading trajectory frame 800
# ()
# Reading trajectory frame 801
# ()
# Reading trajectory frame 802
# ()
# Reading trajectory frame 803
# ()
# Reading trajectory frame 804
# ()
# Reading trajectory frame 805
# ()
# Reading trajectory frame 806
# ()
# Reading trajectory frame 807
# ()
# Reading trajectory frame 808
# ()
# Reading trajectory frame 809
# ()
# Reading trajectory frame 810
# ()
# Reading trajectory frame 811
# ()
# Reading trajectory frame 812
# ()
# Reading trajectory frame 813
# ()
# Reading trajectory frame 814
# ()
# Reading trajectory frame 815
# ()
# Reading trajectory frame 816
# ()
# Reading trajectory frame 817
# ()
# Reading trajectory frame 818
# ()
# Reading trajectory frame 819
# ()
# Reading trajectory frame 820
# ()
# Reading trajectory frame 821
# ()
# Reading trajectory frame 822
# ()
# Reading trajectory frame 823
# ()
# Reading trajectory frame 824
# ()
# Reading trajectory frame 825
# ()
# Reading trajectory frame 826
# ()
# Reading trajectory frame 827
# ()
# Reading trajectory frame 828
# ()
# Reading trajectory frame 829
# ()
# Reading trajectory frame 830
# ()
# Reading trajectory frame 831
# ()
# Reading trajectory frame 832
# ()
# Reading trajectory frame 833
# ()
# Reading trajectory frame 834
# ()
# Reading trajectory frame 835
# ()
# Reading trajectory frame 836
# ()
# Reading trajectory frame 837
# ()
# Reading trajectory frame 838
# ()
# Reading trajectory frame 839
# ()
# Reading trajectory frame 840
# ()
# Reading trajectory frame 841
# ()
# Reading trajectory frame 842
# ()
# Reading trajectory frame 843
# ()
# Reading trajectory frame 844
# ()
# Reading trajectory frame 845
# ()
# Reading trajectory frame 846
# ()
# Reading trajectory frame 847
# ()
# Reading trajectory frame 848
# ()
# Reading trajectory frame 849
# ()
# Reading trajectory frame 850
# ()
# Reading trajectory frame 851
# ()
# Reading trajectory frame 852
# ()
# Reading trajectory frame 853
# ()
# Reading trajectory frame 854
# ()
# Reading trajectory frame 855
# ()
# Reading trajectory frame 856
# ()
# Reading trajectory frame 857
# ()
# Reading trajectory frame 858
# ()
# Reading trajectory frame 859
# ()
# Reading trajectory frame 860
# ()
# Reading trajectory frame 861
# ()
# Reading trajectory frame 862
# ()
# Reading trajectory frame 863
# ()
# Reading trajectory frame 864
# ()
# Reading trajectory frame 865
# ()
# Reading trajectory frame 866
# ()
# Reading trajectory frame 867
# ()
# Reading trajectory frame 868
# ()
# Reading trajectory frame 869
# ()
# Reading trajectory frame 870
# ()
# Reading trajectory frame 871
# ()
# Reading trajectory frame 872
# ()
# Reading trajectory frame 873
# ()
# Reading trajectory frame 874
# ()
# Reading trajectory frame 875
# ()
# Reading trajectory frame 876
# ()
# Reading trajectory frame 877
# ()
# Reading trajectory frame 878
# ()
# Reading trajectory frame 879
# ()
# Reading trajectory frame 880
# ()
# Reading trajectory frame 881
# ()
# Reading trajectory frame 882
# ()
# Reading trajectory frame 883
# ()
# Reading trajectory frame 884
# ()
# Reading trajectory frame 885
# ()
# Reading trajectory frame 886
# ()
# Reading trajectory frame 887
# ()
# Reading trajectory frame 888
# ()
# Reading trajectory frame 889
# ()
# Reading trajectory frame 890
# ()
# Reading trajectory frame 891
# ()
# Reading trajectory frame 892
# ()
# Reading trajectory frame 893
# ()
# Reading trajectory frame 894
# ()
# Reading trajectory frame 895
# ()
# Reading trajectory frame 896
# ()
# Reading trajectory frame 897
# ()
# Reading trajectory frame 898
# ()
# Reading trajectory frame 899
# ()
# Reading trajectory frame 900
# ()
# Reading trajectory frame 901
# ()
# Reading trajectory frame 902
# ()
# Reading trajectory frame 903
# ()
# Reading trajectory frame 904
# ()
# Reading trajectory frame 905
# ()
# Reading trajectory frame 906
# ()
# Reading trajectory frame 907
# ()
# Reading trajectory frame 908
# ()
# Reading trajectory frame 909
# ()
# Reading trajectory frame 910
# ()
# Reading trajectory frame 911
# ()
# Reading trajectory frame 912
# ()
# Reading trajectory frame 913
# ()
# Reading trajectory frame 914
# ()
# Reading trajectory frame 915
# ()
# Reading trajectory frame 916
# ()
# Reading trajectory frame 917
# ()
# Reading trajectory frame 918
# ()
# Reading trajectory frame 919
# ()
# Reading trajectory frame 920
# ()
# Reading trajectory frame 921
# ()
# Reading trajectory frame 922
# ()
# Reading trajectory frame 923
# ()
# Reading trajectory frame 924
# ()
# Reading trajectory frame 925
# ()
# Reading trajectory frame 926
# ()
# Reading trajectory frame 927
# ()
# Reading trajectory frame 928
# ()
# Reading trajectory frame 929
# ()
# Reading trajectory frame 930
# ()
# Reading trajectory frame 931
# ()
# Reading trajectory frame 932
# ()
# Reading trajectory frame 933
# ()
# Reading trajectory frame 934
# ()
# Reading trajectory frame 935
# ()
# Reading trajectory frame 936
# ()
# Reading trajectory frame 937
# ()
# Reading trajectory frame 938
# ()
# Reading trajectory frame 939
# ()
# Reading trajectory frame 940
# ()
# Reading trajectory frame 941
# ()
# Reading trajectory frame 942
# ()
# Reading trajectory frame 943
# ()
# Reading trajectory frame 944
# ()
# Reading trajectory frame 945
# ()
# Reading trajectory frame 946
# ()
# Reading trajectory frame 947
# ()
# Reading trajectory frame 948
# ()
# Reading trajectory frame 949
# ()
# Reading trajectory frame 950
# ()
# Reading trajectory frame 951
# ()
# Reading trajectory frame 952
# ()
# Reading trajectory frame 953
# ()
# Reading trajectory frame 954
# ()
# Reading trajectory frame 955
# ()
# Reading trajectory frame 956
# ()
# Reading trajectory frame 957
# ()
# Reading trajectory frame 958
# ()
# Reading trajectory frame 959
# ()
# Reading trajectory frame 960
# ()
# Reading trajectory frame 961
# ()
# Reading trajectory frame 962
# ()
# Reading trajectory frame 963
# ()
# Reading trajectory frame 964
# ()
# Reading trajectory frame 965
# ()
# Reading trajectory frame 966
# ()
# Reading trajectory frame 967
# ()
# Reading trajectory frame 968
# ()
# Reading trajectory frame 969
# ()
# Reading trajectory frame 970
# ()
# Reading trajectory frame 971
# ()
# Reading trajectory frame 972
# ()
# Reading trajectory frame 973
# ()
# Reading trajectory frame 974
# ()
# Reading trajectory frame 975
# ()
# Reading trajectory frame 976
# ()
# Reading trajectory frame 977
# ()
# Reading trajectory frame 978
# ()
# Reading trajectory frame 979
# ()
# Reading trajectory frame 980
# ()
# Reading trajectory frame 981
# ()
# Reading trajectory frame 982
# ()
# Reading trajectory frame 983
# ()
# Reading trajectory frame 984
# ()
# Reading trajectory frame 985
# ()
# Reading trajectory frame 986
# ()
# Reading trajectory frame 987
# ()
# Reading trajectory frame 988
# ()
# Reading trajectory frame 989
# ()
# Reading trajectory frame 990
# ()
# Reading trajectory frame 991
# ()
# Reading trajectory frame 992
# ()
# Reading trajectory frame 993
# ()
# Reading trajectory frame 994
# ()
# Reading trajectory frame 995
# ()
# Reading trajectory frame 996
# ()
# Reading trajectory frame 997
# ()
# Reading trajectory frame 998
# ()
# Reading trajectory frame 999
# ()
# Reading trajectory frame 1000
# ()
# Reading trajectory frame 1001
# ()
# Reading trajectory frame 1002
# ()
# Reading trajectory frame 1003
# ()
# Reading trajectory frame 1004
# ()
# Reading trajectory frame 1005
# ()
# Reading trajectory frame 1006
# ()
# Reading trajectory frame 1007
# ()
# Reading trajectory frame 1008
# ()
# Reading trajectory frame 1009
# ()
# Reading trajectory frame 1010
# ()
# Reading trajectory frame 1011
# ()
# Reading trajectory frame 1012
# ()
# Reading trajectory frame 1013
# ()
# Reading trajectory frame 1014
# ()
# Reading trajectory frame 1015
# ()
# Reading trajectory frame 1016
# ()
# Reading trajectory frame 1017
# ()
# Reading trajectory frame 1018
# ()
# Reading trajectory frame 1019
# ()
# Reading trajectory frame 1020
# ()
# Reading trajectory frame 1021
# ()
# Reading trajectory frame 1022
# ()
# Reading trajectory frame 1023
# ()
# Reading trajectory frame 1024
# ()
# Reading trajectory frame 1025
# ()
# Reading trajectory frame 1026
# ()
# Reading trajectory frame 1027
# ()
# Reading trajectory frame 1028
# ()
# Reading trajectory frame 1029
# ()
# Reading trajectory frame 1030
# ()
# Reading trajectory frame 1031
# ()
# Reading trajectory frame 1032
# ()
# Reading trajectory frame 1033
# ()
# Reading trajectory frame 1034
# ()
# Reading trajectory frame 1035
# ()
# Reading trajectory frame 1036
# ()
# Reading trajectory frame 1037
# ()
# Reading trajectory frame 1038
# ()
# Reading trajectory frame 1039
# ()
# Reading trajectory frame 1040
# ()
# Reading trajectory frame 1041
# ()
# Reading trajectory frame 1042
# ()
# Reading trajectory frame 1043
# ()
# Reading trajectory frame 1044
# ()
# Reading trajectory frame 1045
# ()
# Reading trajectory frame 1046
# ()
# Reading trajectory frame 1047
# ()
# Reading trajectory frame 1048
# ()
# Reading trajectory frame 1049
# ()
# Reading trajectory frame 1050
# ()
# Reading trajectory frame 1051
# ()
# Reading trajectory frame 1052
# ()
# Reading trajectory frame 1053
# ()
# Reading trajectory frame 1054
# ()
# Reading trajectory frame 1055
# ()
# Reading trajectory frame 1056
# ()
# Reading trajectory frame 1057
# ()
# Reading trajectory frame 1058
# ()
# Reading trajectory frame 1059
# ()
# Reading trajectory frame 1060
# ()
# Reading trajectory frame 1061
# ()
# Reading trajectory frame 1062
# ()
# Reading trajectory frame 1063
# ()
# Reading trajectory frame 1064
# ()
# Reading trajectory frame 1065
# ()
# Reading trajectory frame 1066
# ()
# Reading trajectory frame 1067
# ()
# Reading trajectory frame 1068
# ()
# Reading trajectory frame 1069
# ()
# Reading trajectory frame 1070
# ()
# Reading trajectory frame 1071
# ()
# Reading trajectory frame 1072
# ()
# Reading trajectory frame 1073
# ()
# Reading trajectory frame 1074
# ()
# Reading trajectory frame 1075
# ()
# Reading trajectory frame 1076
# ()
# Reading trajectory frame 1077
# ()
# Reading trajectory frame 1078
# ()
# Reading trajectory frame 1079
# ()
# Reading trajectory frame 1080
# ()
# Reading trajectory frame 1081
# ()
# Reading trajectory frame 1082
# ()
# Reading trajectory frame 1083
# ()
# Reading trajectory frame 1084
# ()
# Reading trajectory frame 1085
# ()
# Reading trajectory frame 1086
# ()
# Reading trajectory frame 1087
# ()
# Reading trajectory frame 1088
# ()
# Reading trajectory frame 1089
# ()
# Reading trajectory frame 1090
# ()
# Reading trajectory frame 1091
# ()
# Reading trajectory frame 1092
# ()
# Reading trajectory frame 1093
# ()
# Reading trajectory frame 1094
# ()
# Reading trajectory frame 1095
# ()
# Reading trajectory frame 1096
# ()
# Reading trajectory frame 1097
# ()
# Reading trajectory frame 1098
# ()
# Reading trajectory frame 1099
# ()
# Reading trajectory frame 1100
# ()
# Reading trajectory frame 1101
# ()
# Reading trajectory frame 1102
# ()
# Reading trajectory frame 1103
# ()
# Reading trajectory frame 1104
# ()
# Reading trajectory frame 1105
# ()
# Reading trajectory frame 1106
# ()
# Reading trajectory frame 1107
# ()
# Reading trajectory frame 1108
# ()
# Reading trajectory frame 1109
# ()
# Reading trajectory frame 1110
# ()
# Reading trajectory frame 1111
# ()
# Reading trajectory frame 1112
# ()
# Reading trajectory frame 1113
# ()
# Reading trajectory frame 1114
# ()
# Reading trajectory frame 1115
# ()
# Reading trajectory frame 1116
# ()
# Reading trajectory frame 1117
# ()
# Reading trajectory frame 1118
# ()
# Reading trajectory frame 1119
# ()
# Reading trajectory frame 1120
# ()
# Reading trajectory frame 1121
# ()
# Reading trajectory frame 1122
# ()
# Reading trajectory frame 1123
# ()
# Reading trajectory frame 1124
# ()
# Reading trajectory frame 1125
# ()
# Reading trajectory frame 1126
# ()
# Reading trajectory frame 1127
# ()
# Reading trajectory frame 1128
# ()
# Reading trajectory frame 1129
# ()
# Reading trajectory frame 1130
# ()
# Reading trajectory frame 1131
# ()
# Reading trajectory frame 1132
# ()
# Reading trajectory frame 1133
# ()
# Reading trajectory frame 1134
# ()
# Reading trajectory frame 1135
# ()
# Reading trajectory frame 1136
# ()
# Reading trajectory frame 1137
# ()
# Reading trajectory frame 1138
# ()
# Reading trajectory frame 1139
# ()
# Reading trajectory frame 1140
# ()
# Reading trajectory frame 1141
# ()
# Reading trajectory frame 1142
# ()
# Reading trajectory frame 1143
# ()
# Reading trajectory frame 1144
# ()
# Reading trajectory frame 1145
# ()
# Reading trajectory frame 1146
# ()
# Reading trajectory frame 1147
# ()
# Reading trajectory frame 1148
# ()
# Reading trajectory frame 1149
# ()
# Reading trajectory frame 1150
# ()
# Reading trajectory frame 1151
# ()
# Reading trajectory frame 1152
# ()
# Reading trajectory frame 1153
# ()
# Reading trajectory frame 1154
# ()
# Reading trajectory frame 1155
# ()
# Reading trajectory frame 1156
# ()
# Reading trajectory frame 1157
# ()
# Reading trajectory frame 1158
# ()
# Reading trajectory frame 1159
# ()
# Reading trajectory frame 1160
# ()
# Reading trajectory frame 1161
# ()
# Reading trajectory frame 1162
# ()
# Reading trajectory frame 1163
# ()
# Reading trajectory frame 1164
# ()
# Reading trajectory frame 1165
# ()
# Reading trajectory frame 1166
# ()
# Reading trajectory frame 1167
# ()
# Reading trajectory frame 1168
# ()
# Reading trajectory frame 1169
# ()
# Reading trajectory frame 1170
# ()
# Reading trajectory frame 1171
# ()
# Reading trajectory frame 1172
# ()
# Reading trajectory frame 1173
# ()
# Reading trajectory frame 1174
# ()
# Reading trajectory frame 1175
# ()
# Reading trajectory frame 1176
# ()
# Reading trajectory frame 1177
# ()
# Reading trajectory frame 1178
# ()
# Reading trajectory frame 1179
# ()
# Reading trajectory frame 1180
# ()
# Reading trajectory frame 1181
# ()
# Reading trajectory frame 1182
# ()
# Reading trajectory frame 1183
# ()
# Reading trajectory frame 1184
# ()
# Reading trajectory frame 1185
# ()
# Reading trajectory frame 1186
# ()
# Reading trajectory frame 1187
# ()
# Reading trajectory frame 1188
# ()
# Reading trajectory frame 1189
# ()
# Reading trajectory frame 1190
# ()
# Reading trajectory frame 1191
# ()
# Reading trajectory frame 1192
# ()
# Reading trajectory frame 1193
# ()
# Reading trajectory frame 1194
# ()
# Reading trajectory frame 1195
# ()
# Reading trajectory frame 1196
# ()
# Reading trajectory frame 1197
# ()
# Reading trajectory frame 1198
# ()
# Reading trajectory frame 1199
# ()
# Reading trajectory frame 1200
# ()
# Reading trajectory frame 1201
# ()
# Reading trajectory frame 1202
# ()
# Reading trajectory frame 1203
# ()
# Reading trajectory frame 1204
# ()
# Reading trajectory frame 1205
# ()
# Reading trajectory frame 1206
# ()
# Reading trajectory frame 1207
# ()
# Reading trajectory frame 1208
# ()
# Reading trajectory frame 1209
# ()
# Reading trajectory frame 1210
# ()
# Reading trajectory frame 1211
# ()
# Reading trajectory frame 1212
# ()
# Reading trajectory frame 1213
# ()
# Reading trajectory frame 1214
# ()
# Reading trajectory frame 1215
# ()
# Reading trajectory frame 1216
# ()
# Reading trajectory frame 1217
# ()
# Reading trajectory frame 1218
# ()
# Reading trajectory frame 1219
# ()
# Reading trajectory frame 1220
# ()
# Reading trajectory frame 1221
# ()
# Reading trajectory frame 1222
# ()
# Reading trajectory frame 1223
# ()
# Reading trajectory frame 1224
# ()
# Reading trajectory frame 1225
# ()
# Reading trajectory frame 1226
# ()
# Reading trajectory frame 1227
# ()
# Reading trajectory frame 1228
# ()
# Reading trajectory frame 1229
# ()
# Reading trajectory frame 1230
# ()
# Reading trajectory frame 1231
# ()
# Reading trajectory frame 1232
# ()
# Reading trajectory frame 1233
# ()
# Reading trajectory frame 1234
# ()
# Reading trajectory frame 1235
# ()
# Reading trajectory frame 1236
# ()
# Reading trajectory frame 1237
# ()
# Reading trajectory frame 1238
# ()
# Reading trajectory frame 1239
# ()
# Reading trajectory frame 1240
# ()
# Reading trajectory frame 1241
# ()
# Reading trajectory frame 1242
# ()
# Reading trajectory frame 1243
# ()
# Reading trajectory frame 1244
# ()
# Reading trajectory frame 1245
# ()
# Reading trajectory frame 1246
# ()
# Reading trajectory frame 1247
# ()
# Reading trajectory frame 1248
# ()
# Reading trajectory frame 1249
# ()
# Reading trajectory frame 1250
# ()
# Reading trajectory frame 1251
# ()
# Reading trajectory frame 1252
# ()
# Reading trajectory frame 1253
# ()
# Reading trajectory frame 1254
# ()
# Reading trajectory frame 1255
# ()
# Reading trajectory frame 1256
# ()
# Reading trajectory frame 1257
# ()
# Reading trajectory frame 1258
# ()
# Reading trajectory frame 1259
# ()
# Reading trajectory frame 1260
# ()
# Reading trajectory frame 1261
# ()
# Reading trajectory frame 1262
# ()
# Reading trajectory frame 1263
# ()
# Reading trajectory frame 1264
# ()
# Reading trajectory frame 1265
# ()
# Reading trajectory frame 1266
# ()
# Reading trajectory frame 1267
# ()
# Reading trajectory frame 1268
# ()
# Reading trajectory frame 1269
# ()
# Reading trajectory frame 1270
# ()
# Reading trajectory frame 1271
# ()
# Reading trajectory frame 1272
# ()
# Reading trajectory frame 1273
# ()
# Reading trajectory frame 1274
# ()
# Reading trajectory frame 1275
# ()
# Reading trajectory frame 1276
# ()
# Reading trajectory frame 1277
# ()
# Reading trajectory frame 1278
# ()
# Reading trajectory frame 1279
# ()
# Reading trajectory frame 1280
# ()
# Reading trajectory frame 1281
# ()
# Reading trajectory frame 1282
# ()
# Reading trajectory frame 1283
# ()
# Reading trajectory frame 1284
# ()
# Reading trajectory frame 1285
# ()
# Reading trajectory frame 1286
# ()
# Reading trajectory frame 1287
# ()
# Reading trajectory frame 1288
# ()
# Reading trajectory frame 1289
# ()
# Reading trajectory frame 1290
# ()
# Reading trajectory frame 1291
# ()
# Reading trajectory frame 1292
# ()
# Reading trajectory frame 1293
# ()
# Reading trajectory frame 1294
# ()
# Reading trajectory frame 1295
# ()
# Reading trajectory frame 1296
# ()
# Reading trajectory frame 1297
# ()
# Reading trajectory frame 1298
# ()
# Reading trajectory frame 1299
# ()
# Reading trajectory frame 1300
# ()
# Reading trajectory frame 1301
# ()
# Reading trajectory frame 1302
# ()
# Reading trajectory frame 1303
# ()
# Reading trajectory frame 1304
# ()
# Reading trajectory frame 1305
# ()
# Reading trajectory frame 1306
# ()
# Reading trajectory frame 1307
# ()
# Reading trajectory frame 1308
# ()
# Reading trajectory frame 1309
# ()
# Reading trajectory frame 1310
# ()
# Reading trajectory frame 1311
# ()
# Reading trajectory frame 1312
# ()
# Reading trajectory frame 1313
# ()
# Reading trajectory frame 1314
# ()
# Reading trajectory frame 1315
# ()
# Reading trajectory frame 1316
# ()
# Reading trajectory frame 1317
# ()
# Reading trajectory frame 1318
# ()
# Reading trajectory frame 1319
# ()
# Reading trajectory frame 1320
# ()
# Reading trajectory frame 1321
# ()
# Reading trajectory frame 1322
# ()
# Reading trajectory frame 1323
# ()
# Reading trajectory frame 1324
# ()
# Reading trajectory frame 1325
# ()
# Reading trajectory frame 1326
# ()
# Reading trajectory frame 1327
# ()
# Reading trajectory frame 1328
# ()
# Reading trajectory frame 1329
# ()
# Reading trajectory frame 1330
# ()
# Reading trajectory frame 1331
# ()
# Reading trajectory frame 1332
# ()
# Reading trajectory frame 1333
# ()
# Reading trajectory frame 1334
# ()
# Reading trajectory frame 1335
# ()
# Reading trajectory frame 1336
# ()
# Reading trajectory frame 1337
# ()
# Reading trajectory frame 1338
# ()
# Reading trajectory frame 1339
# ()
# Reading trajectory frame 1340
# ()
# Reading trajectory frame 1341
# ()
# Reading trajectory frame 1342
# ()
# Reading trajectory frame 1343
# ()
# Reading trajectory frame 1344
# ()
# Reading trajectory frame 1345
# ()
# Reading trajectory frame 1346
# ()
# Reading trajectory frame 1347
# ()
# Reading trajectory frame 1348
# ()
# Reading trajectory frame 1349
# ()
# Reading trajectory frame 1350
# ()
# Reading trajectory frame 1351
# ()
# Reading trajectory frame 1352
# ()
# Reading trajectory frame 1353
# ()
# Reading trajectory frame 1354
# ()
# Reading trajectory frame 1355
# ()
# Reading trajectory frame 1356
# ()
# Reading trajectory frame 1357
# ()
# Reading trajectory frame 1358
# ()
# Reading trajectory frame 1359
# ()
# Reading trajectory frame 1360
# ()
# Reading trajectory frame 1361
# ()
# Reading trajectory frame 1362
# ()
# Reading trajectory frame 1363
# ()
# Reading trajectory frame 1364
# ()
# Reading trajectory frame 1365
# ()
# Reading trajectory frame 1366
# ()
# Reading trajectory frame 1367
# ()
# Reading trajectory frame 1368
# ()
# Reading trajectory frame 1369
# ()
# Reading trajectory frame 1370
# ()
# Reading trajectory frame 1371
# ()
# Reading trajectory frame 1372
# ()
# Reading trajectory frame 1373
# ()
# Reading trajectory frame 1374
# ()
# Reading trajectory frame 1375
# ()
# Reading trajectory frame 1376
# ()
# Reading trajectory frame 1377
# ()
# Reading trajectory frame 1378
# ()
# Reading trajectory frame 1379
# ()
# Reading trajectory frame 1380
# ()
# Reading trajectory frame 1381
# ()
# Reading trajectory frame 1382
# ()
# Reading trajectory frame 1383
# ()
# Reading trajectory frame 1384
# ()
# Reading trajectory frame 1385
# ()
# Reading trajectory frame 1386
# ()
# Reading trajectory frame 1387
# ()
# Reading trajectory frame 1388
# ()
# Reading trajectory frame 1389
# ()
# Reading trajectory frame 1390
# ()
# Reading trajectory frame 1391
# ()
# Reading trajectory frame 1392
# ()
# Reading trajectory frame 1393
# ()
# Reading trajectory frame 1394
# ()
# Reading trajectory frame 1395
# ()
# Reading trajectory frame 1396
# ()
# Reading trajectory frame 1397
# ()
# Reading trajectory frame 1398
# ()
# Reading trajectory frame 1399
# ()
# Reading trajectory frame 1400
# ()
# Reading trajectory frame 1401
# ()
# Reading trajectory frame 1402
# ()
# Reading trajectory frame 1403
# ()
# Reading trajectory frame 1404
# ()
# Reading trajectory frame 1405
# ()
# Reading trajectory frame 1406
# ()
# Reading trajectory frame 1407
# ()
# Reading trajectory frame 1408
# ()
# Reading trajectory frame 1409
# ()
# Reading trajectory frame 1410
# ()
# Reading trajectory frame 1411
# ()
# Reading trajectory frame 1412
# ()
# Reading trajectory frame 1413
# ()
# Reading trajectory frame 1414
# ()
# Reading trajectory frame 1415
# ()
# Reading trajectory frame 1416
# ()
# Reading trajectory frame 1417
# ()
# Reading trajectory frame 1418
# ()
# Reading trajectory frame 1419
# ()
# Reading trajectory frame 1420
# ()
# Reading trajectory frame 1421
# ()
# Reading trajectory frame 1422
# ()
# Reading trajectory frame 1423
# ()
# Reading trajectory frame 1424
# ()
# Reading trajectory frame 1425
# ()
# Reading trajectory frame 1426
# ()
# Reading trajectory frame 1427
# ()
# Reading trajectory frame 1428
# ()
# Reading trajectory frame 1429
# ()
# Reading trajectory frame 1430
# ()
# Reading trajectory frame 1431
# ()
# Reading trajectory frame 1432
# ()
# Reading trajectory frame 1433
# ()
# Reading trajectory frame 1434
# ()
# Reading trajectory frame 1435
# ()
# Reading trajectory frame 1436
# ()
# Reading trajectory frame 1437
# ()
# Reading trajectory frame 1438
# ()
# Reading trajectory frame 1439
# ()
# Reading trajectory frame 1440
# ()
# Reading trajectory frame 1441
# ()
# Reading trajectory frame 1442
# ()
# Reading trajectory frame 1443
# ()
# Reading trajectory frame 1444
# ()
# Reading trajectory frame 1445
# ()
# Reading trajectory frame 1446
# ()
# Reading trajectory frame 1447
# ()
# Reading trajectory frame 1448
# ()
# Reading trajectory frame 1449
# ()
# Reading trajectory frame 1450
# ()
# Reading trajectory frame 1451
# ()
# Reading trajectory frame 1452
# ()
# Reading trajectory frame 1453
# ()
# Reading trajectory frame 1454
# ()
# Reading trajectory frame 1455
# ()
# Reading trajectory frame 1456
# ()
# Reading trajectory frame 1457
# ()
# Reading trajectory frame 1458
# ()
# Reading trajectory frame 1459
# ()
# Reading trajectory frame 1460
# ()
# Reading trajectory frame 1461
# ()
# Reading trajectory frame 1462
# ()
# Reading trajectory frame 1463
# ()
# Reading trajectory frame 1464
# ()
# Reading trajectory frame 1465
# ()
# Reading trajectory frame 1466
# ()
# Reading trajectory frame 1467
# ()
# Reading trajectory frame 1468
# ()
# Reading trajectory frame 1469
# ()
# Reading trajectory frame 1470
# ()
# Reading trajectory frame 1471
# ()
# Reading trajectory frame 1472
# ()
# Reading trajectory frame 1473
# ()
# Reading trajectory frame 1474
# ()
# Reading trajectory frame 1475
# ()
# Reading trajectory frame 1476
# ()
# Reading trajectory frame 1477
# ()
# Reading trajectory frame 1478
# ()
# Reading trajectory frame 1479
# ()
# Reading trajectory frame 1480
# ()
# Reading trajectory frame 1481
# ()
# Reading trajectory frame 1482
# ()
# Reading trajectory frame 1483
# ()
# Reading trajectory frame 1484
# ()
# Reading trajectory frame 1485
# ()
# ...
# ()
# Reading trajectory frame 3511
# ()
# Reading trajectory frame 3512
# ()
# Reading trajectory frame 3513
# ()
# Reading trajectory frame 3514
# ()
# Reading trajectory frame 3515
# ()
# Reading trajectory frame 3516
# ()
# Reading trajectory frame 3517
# ()
# Reading trajectory frame 3518
# ()
# Reading trajectory frame 3519
# ()
# Reading trajectory frame 3520
# ()
# Reading trajectory frame 3521
# ()
# Reading trajectory frame 3522
# ()
# Reading trajectory frame 3523
# ()
# Reading trajectory frame 3524
# ()
# Reading trajectory frame 3525
# ()
# Reading trajectory frame 3526
# ()
# Reading trajectory frame 3527
# ()
# Reading trajectory frame 3528
# ()
# Reading trajectory frame 3529
# ()
# Reading trajectory frame 3530
# ()
# Reading trajectory frame 3531
# ()
# Reading trajectory frame 3532
# ()
# Reading trajectory frame 3533
# ()
# Reading trajectory frame 3534
# ()
# Reading trajectory frame 3535
# ()
# Reading trajectory frame 3536
# ()
# Reading trajectory frame 3537
# ()
# Reading trajectory frame 3538
# ()
# Reading trajectory frame 3539
# ()
# Reading trajectory frame 3540
# ()
# Reading trajectory frame 3541
# ()
# Reading trajectory frame 3542
# ()
# Reading trajectory frame 3543
# ()
# Reading trajectory frame 3544
# ()
# Reading trajectory frame 3545
# ()
# Reading trajectory frame 3546
# ()
# Reading trajectory frame 3547
# ()
# Reading trajectory frame 3548
# ()
# Reading trajectory frame 3549
# ()
# Reading trajectory frame 3550
# ()
# Reading trajectory frame 3551
# ()
# Reading trajectory frame 3552
# ()
# Reading trajectory frame 3553
# ()
# Reading trajectory frame 3554
# ()
# Reading trajectory frame 3555
# ()
# Reading trajectory frame 3556
# ()
# Reading trajectory frame 3557
# ()
# Reading trajectory frame 3558
# ()
# Reading trajectory frame 3559
# ()
# Reading trajectory frame 3560
# ()
# Reading trajectory frame 3561
# ()
# Reading trajectory frame 3562
# ()
# Reading trajectory frame 3563
# ()
# Reading trajectory frame 3564
# ()
# Reading trajectory frame 3565
# ()
# Reading trajectory frame 3566
# ()
# Reading trajectory frame 3567
# ()
# Reading trajectory frame 3568
# ()
# Reading trajectory frame 3569
# ()
# Reading trajectory frame 3570
# ()
# Reading trajectory frame 3571
# ()
# Reading trajectory frame 3572
# ()
# Reading trajectory frame 3573
# ()
# Reading trajectory frame 3574
# ()
# Reading trajectory frame 3575
# ()
# Reading trajectory frame 3576
# ()
# Reading trajectory frame 3577
# ()
# Reading trajectory frame 3578
# ()
# Reading trajectory frame 3579
# ()
# Reading trajectory frame 3580
# ()
# Reading trajectory frame 3581
# ()
# Reading trajectory frame 3582
# ()
# Reading trajectory frame 3583
# ()
# Reading trajectory frame 3584
# ()
# Reading trajectory frame 3585
# ()
# Reading trajectory frame 3586
# ()
# Reading trajectory frame 3587
# ()
# Reading trajectory frame 3588
# ()
# Reading trajectory frame 3589
# ()
# Reading trajectory frame 3590
# ()
# Reading trajectory frame 3591
# ()
# Reading trajectory frame 3592
# ()
# Reading trajectory frame 3593
# ()
# Reading trajectory frame 3594
# ()
# Reading trajectory frame 3595
# ()
# Reading trajectory frame 3596
# ()
# Reading trajectory frame 3597
# ()
# Reading trajectory frame 3598
# ()
# Reading trajectory frame 3599
# ()
# Reading trajectory frame 3600
# ()
# Reading trajectory frame 3601
# ()
# Reading trajectory frame 3602
# ()
# Reading trajectory frame 3603
# ()
# Reading trajectory frame 3604
# ()
# Reading trajectory frame 3605
# ()
# Reading trajectory frame 3606
# ()
# Reading trajectory frame 3607
# ()
# Reading trajectory frame 3608
# ()
# Reading trajectory frame 3609
# ()
# Reading trajectory frame 3610
# ()
# Reading trajectory frame 3611
# ()
# Reading trajectory frame 3612
# ()
# Reading trajectory frame 3613
# ()
# Reading trajectory frame 3614
# ()
# Reading trajectory frame 3615
# ()
# Reading trajectory frame 3616
# ()
# Reading trajectory frame 3617
# ()
# Reading trajectory frame 3618
# ()
# Reading trajectory frame 3619
# ()
# Reading trajectory frame 3620
# ()
# Reading trajectory frame 3621
# ()
# Reading trajectory frame 3622
# ()
# Reading trajectory frame 3623
# ()
# Reading trajectory frame 3624
# ()
# Reading trajectory frame 3625
# ()
# Reading trajectory frame 3626
# ()
# Reading trajectory frame 3627
# ()
# Reading trajectory frame 3628
# ()
# Reading trajectory frame 3629
# ()
# Reading trajectory frame 3630
# ()
# Reading trajectory frame 3631
# ()
# Reading trajectory frame 3632
# ()
# Reading trajectory frame 3633
# ()
# Reading trajectory frame 3634
# ()
# Reading trajectory frame 3635
# ()
# Reading trajectory frame 3636
# ()
# Reading trajectory frame 3637
# ()
# Reading trajectory frame 3638
# ()
# Reading trajectory frame 3639
# ()
# Reading trajectory frame 3640
# ()
# Reading trajectory frame 3641
# ()
# Reading trajectory frame 3642
# ()
# Reading trajectory frame 3643
# ()
# Reading trajectory frame 3644
# ()
# Reading trajectory frame 3645
# ()
# Reading trajectory frame 3646
# ()
# Reading trajectory frame 3647
# ()
# Reading trajectory frame 3648
# ()
# Reading trajectory frame 3649
# ()
# Reading trajectory frame 3650
# ()
# Reading trajectory frame 3651
# ()
# Reading trajectory frame 3652
# ()
# Reading trajectory frame 3653
# ()
# Reading trajectory frame 3654
# ()
# Reading trajectory frame 3655
# ()
# Reading trajectory frame 3656
# ()
# Reading trajectory frame 3657
# ()
# Reading trajectory frame 3658
# ()
# Reading trajectory frame 3659
# ()
# Reading trajectory frame 3660
# ()
# Reading trajectory frame 3661
# ()
# Reading trajectory frame 3662
# ()
# Reading trajectory frame 3663
# ()
# Reading trajectory frame 3664
# ()
# Reading trajectory frame 3665
# ()
# Reading trajectory frame 3666
# ()
# Reading trajectory frame 3667
# ()
# Reading trajectory frame 3668
# ()
# Reading trajectory frame 3669
# ()
# Reading trajectory frame 3670
# ()
# Reading trajectory frame 3671
# ()
# Reading trajectory frame 3672
# ()
# Reading trajectory frame 3673
# ()
# Reading trajectory frame 3674
# ()
# Reading trajectory frame 3675
# ()
# Reading trajectory frame 3676
# ()
# Reading trajectory frame 3677
# ()
# Reading trajectory frame 3678
# ()
# Reading trajectory frame 3679
# ()
# Reading trajectory frame 3680
# ()
# Reading trajectory frame 3681
# ()
# Reading trajectory frame 3682
# ()
# Reading trajectory frame 3683
# ()
# Reading trajectory frame 3684
# ()
# Reading trajectory frame 3685
# ()
# Reading trajectory frame 3686
# ()
# Reading trajectory frame 3687
# ()
# Reading trajectory frame 3688
# ()
# Reading trajectory frame 3689
# ()
# Reading trajectory frame 3690
# ()
# Reading trajectory frame 3691
# ()
# Reading trajectory frame 3692
# ()
# Reading trajectory frame 3693
# ()
# Reading trajectory frame 3694
# ()
# Reading trajectory frame 3695
# ()
# Reading trajectory frame 3696
# ()
# Reading trajectory frame 3697
# ()
# Reading trajectory frame 3698
# ()
# Reading trajectory frame 3699
# ()
# Reading trajectory frame 3700
# ()
# Reading trajectory frame 3701
# ()
# Reading trajectory frame 3702
# ()
# Reading trajectory frame 3703
# ()
# Reading trajectory frame 3704
# ()
# Reading trajectory frame 3705
# ()
# Reading trajectory frame 3706
# ()
# Reading trajectory frame 3707
# ()
# Reading trajectory frame 3708
# ()
# Reading trajectory frame 3709
# ()
# Reading trajectory frame 3710
# ()
# Reading trajectory frame 3711
# ()
# Reading trajectory frame 3712
# ()
# Reading trajectory frame 3713
# ()
# Reading trajectory frame 3714
# ()
# Reading trajectory frame 3715
# ()
# Reading trajectory frame 3716
# ()
# Reading trajectory frame 3717
# ()
# Reading trajectory frame 3718
# ()
# Reading trajectory frame 3719
# ()
# Reading trajectory frame 3720
# ()
# Reading trajectory frame 3721
# ()
# Reading trajectory frame 3722
# ()
# Reading trajectory frame 3723
# ()
# Reading trajectory frame 3724
# ()
# Reading trajectory frame 3725
# ()
# Reading trajectory frame 3726
# ()
# Reading trajectory frame 3727
# ()
# Reading trajectory frame 3728
# ()
# Reading trajectory frame 3729
# ()
# Reading trajectory frame 3730
# ()
# Reading trajectory frame 3731
# ()
# Reading trajectory frame 3732
# ()
# Reading trajectory frame 3733
# ()
# Reading trajectory frame 3734
# ()
# Reading trajectory frame 3735
# ()
# Reading trajectory frame 3736
# ()
# Reading trajectory frame 3737
# ()
# Reading trajectory frame 3738
# ()
# Reading trajectory frame 3739
# ()
# Reading trajectory frame 3740
# ()
# Reading trajectory frame 3741
# ()
# Reading trajectory frame 3742
# ()
# Reading trajectory frame 3743
# ()
# Reading trajectory frame 3744
# ()
# Reading trajectory frame 3745
# ()
# Reading trajectory frame 3746
# ()
# Reading trajectory frame 3747
# ()
# Reading trajectory frame 3748
# ()
# Reading trajectory frame 3749
# ()
# Reading trajectory frame 3750
# ()
# Reading trajectory frame 3751
# ()
# Reading trajectory frame 3752
# ()
# Reading trajectory frame 3753
# ()
# Reading trajectory frame 3754
# ()
# Reading trajectory frame 3755
# ()
# Reading trajectory frame 3756
# ()
# Reading trajectory frame 3757
# ()
# Reading trajectory frame 3758
# ()
# Reading trajectory frame 3759
# ()
# Reading trajectory frame 3760
# ()
# Reading trajectory frame 3761
# ()
# Reading trajectory frame 3762
# ()
# Reading trajectory frame 3763
# ()
# Reading trajectory frame 3764
# ()
# Reading trajectory frame 3765
# ()
# Reading trajectory frame 3766
# ()
# Reading trajectory frame 3767
# ()
# Reading trajectory frame 3768
# ()
# Reading trajectory frame 3769
# ()
# Reading trajectory frame 3770
# ()
# Reading trajectory frame 3771
# ()
# Reading trajectory frame 3772
# ()
# Reading trajectory frame 3773
# ()
# Reading trajectory frame 3774
# ()
# Reading trajectory frame 3775
# ()
# Reading trajectory frame 3776
# ()
# Reading trajectory frame 3777
# ()
# Reading trajectory frame 3778
# ()
# Reading trajectory frame 3779
# ()
# Reading trajectory frame 3780
# ()
# Reading trajectory frame 3781
# ()
# Reading trajectory frame 3782
# ()
# Reading trajectory frame 3783
# ()
# Reading trajectory frame 3784
# ()
# Reading trajectory frame 3785
# ()
# Reading trajectory frame 3786
# ()
# Reading trajectory frame 3787
# ()
# Reading trajectory frame 3788
# ()
# Reading trajectory frame 3789
# ()
# Reading trajectory frame 3790
# ()
# Reading trajectory frame 3791
# ()
# Reading trajectory frame 3792
# ()
# Reading trajectory frame 3793
# ()
# Reading trajectory frame 3794
# ()
# Reading trajectory frame 3795
# ()
# Reading trajectory frame 3796
# ()
# Reading trajectory frame 3797
# ()
# Reading trajectory frame 3798
# ()
# Reading trajectory frame 3799
# ()
# Reading trajectory frame 3800
# ()
# Reading trajectory frame 3801
# ()
# Reading trajectory frame 3802
# ()
# Reading trajectory frame 3803
# ()
# Reading trajectory frame 3804
# ()
# Reading trajectory frame 3805
# ()
# Reading trajectory frame 3806
# ()
# Reading trajectory frame 3807
# ()
# Reading trajectory frame 3808
# ()
# Reading trajectory frame 3809
# ()
# Reading trajectory frame 3810
# ()
# Reading trajectory frame 3811
# ()
# Reading trajectory frame 3812
# ()
# Reading trajectory frame 3813
# ()
# Reading trajectory frame 3814
# ()
# Reading trajectory frame 3815
# ()
# Reading trajectory frame 3816
# ()
# Reading trajectory frame 3817
# ()
# Reading trajectory frame 3818
# ()
# Reading trajectory frame 3819
# ()
# Reading trajectory frame 3820
# ()
# Reading trajectory frame 3821
# ()
# Reading trajectory frame 3822
# ()
# Reading trajectory frame 3823
# ()
# Reading trajectory frame 3824
# ()
# Reading trajectory frame 3825
# ()
# Reading trajectory frame 3826
# ()
# Reading trajectory frame 3827
# ()
# Reading trajectory frame 3828
# ()
# Reading trajectory frame 3829
# ()
# Reading trajectory frame 3830
# ()
# Reading trajectory frame 3831
# ()
# Reading trajectory frame 3832
# ()
# Reading trajectory frame 3833
# ()
# Reading trajectory frame 3834
# ()
# Reading trajectory frame 3835
# ()
# Reading trajectory frame 3836
# ()
# Reading trajectory frame 3837
# ()
# Reading trajectory frame 3838
# ()
# Reading trajectory frame 3839
# ()
# Reading trajectory frame 3840
# ()
# Reading trajectory frame 3841
# ()
# Reading trajectory frame 3842
# ()
# Reading trajectory frame 3843
# ()
# Reading trajectory frame 3844
# ()
# Reading trajectory frame 3845
# ()
# Reading trajectory frame 3846
# ()
# Reading trajectory frame 3847
# ()
# Reading trajectory frame 3848
# ()
# Reading trajectory frame 3849
# ()
# Reading trajectory frame 3850
# ()
# Reading trajectory frame 3851
# ()
# Reading trajectory frame 3852
# ()
# Reading trajectory frame 3853
# ()
# Reading trajectory frame 3854
# ()
# Reading trajectory frame 3855
# ()
# Reading trajectory frame 3856
# ()
# Reading trajectory frame 3857
# ()
# Reading trajectory frame 3858
# ()
# Reading trajectory frame 3859
# ()
# Reading trajectory frame 3860
# ()
# Reading trajectory frame 3861
# ()
# Reading trajectory frame 3862
# ()
# Reading trajectory frame 3863
# ()
# Reading trajectory frame 3864
# ()
# Reading trajectory frame 3865
# ()
# Reading trajectory frame 3866
# ()
# Reading trajectory frame 3867
# ()
# Reading trajectory frame 3868
# ()
# Reading trajectory frame 3869
# ()
# Reading trajectory frame 3870
# ()
# Reading trajectory frame 3871
# ()
# Reading trajectory frame 3872
# ()
# Reading trajectory frame 3873
# ()
# Reading trajectory frame 3874
# ()
# Reading trajectory frame 3875
# ()
# Reading trajectory frame 3876
# ()
# Reading trajectory frame 3877
# ()
# Reading trajectory frame 3878
# ()
# Reading trajectory frame 3879
# ()
# Reading trajectory frame 3880
# ()
# Reading trajectory frame 3881
# ()
# Reading trajectory frame 3882
# ()
# Reading trajectory frame 3883
# ()
# Reading trajectory frame 3884
# ()
# Reading trajectory frame 3885
# ()
# Reading trajectory frame 3886
# ()
# Reading trajectory frame 3887
# ()
# Reading trajectory frame 3888
# ()
# Reading trajectory frame 3889
# ()
# Reading trajectory frame 3890
# ()
# Reading trajectory frame 3891
# ()
# Reading trajectory frame 3892
# ()
# Reading trajectory frame 3893
# ()
# Reading trajectory frame 3894
# ()
# Reading trajectory frame 3895
# ()
# Reading trajectory frame 3896
# ()
# Reading trajectory frame 3897
# ()
# Reading trajectory frame 3898
# ()
# Reading trajectory frame 3899
# ()
# Reading trajectory frame 3900
# ()
# Reading trajectory frame 3901
# ()
# Reading trajectory frame 3902
# ()
# Reading trajectory frame 3903
# ()
# Reading trajectory frame 3904
# ()
# Reading trajectory frame 3905
# ()
# Reading trajectory frame 3906
# ()
# Reading trajectory frame 3907
# ()
# Reading trajectory frame 3908
# ()
# Reading trajectory frame 3909
# ()
# Reading trajectory frame 3910
# ()
# Reading trajectory frame 3911
# ()
# Reading trajectory frame 3912
# ()
# Reading trajectory frame 3913
# ()
# Reading trajectory frame 3914
# ()
# Reading trajectory frame 3915
# ()
# Reading trajectory frame 3916
# ()
# Reading trajectory frame 3917
# ()
# Reading trajectory frame 3918
# ()
# Reading trajectory frame 3919
# ()
# Reading trajectory frame 3920
# ()
# Reading trajectory frame 3921
# ()
# Reading trajectory frame 3922
# ()
# Reading trajectory frame 3923
# ()
# Reading trajectory frame 3924
# ()
# Reading trajectory frame 3925
# ()
# Reading trajectory frame 3926
# ()
# Reading trajectory frame 3927
# ()
# Reading trajectory frame 3928
# ()
# Reading trajectory frame 3929
# ()
# Reading trajectory frame 3930
# ()
# Reading trajectory frame 3931
# ()
# Reading trajectory frame 3932
# ()
# Reading trajectory frame 3933
# ()
# Reading trajectory frame 3934
# ()
# Reading trajectory frame 3935
# ()
# Reading trajectory frame 3936
# ()
# Reading trajectory frame 3937
# ()
# Reading trajectory frame 3938
# ()
# Reading trajectory frame 3939
# ()
# Reading trajectory frame 3940
# ()
# Reading trajectory frame 3941
# ()
# Reading trajectory frame 3942
# ()
# Reading trajectory frame 3943
# ()
# Reading trajectory frame 3944
# ()
# Reading trajectory frame 3945
# ()
# Reading trajectory frame 3946
# ()
# Reading trajectory frame 3947
# ()
# Reading trajectory frame 3948
# ()
# Reading trajectory frame 3949
# ()
# Reading trajectory frame 3950
# ()
# Reading trajectory frame 3951
# ()
# Reading trajectory frame 3952
# ()
# Reading trajectory frame 3953
# ()
# Reading trajectory frame 3954
# ()
# Reading trajectory frame 3955
# ()
# Reading trajectory frame 3956
# ()
# Reading trajectory frame 3957
# ()
# Reading trajectory frame 3958
# ()
# Reading trajectory frame 3959
# ()
# Reading trajectory frame 3960
# ()
# Reading trajectory frame 3961
# ()
# Reading trajectory frame 3962
# ()
# Reading trajectory frame 3963
# ()
# Reading trajectory frame 3964
# ()
# Reading trajectory frame 3965
# ()
# Reading trajectory frame 3966
# ()
# Reading trajectory frame 3967
# ()
# Reading trajectory frame 3968
# ()
# Reading trajectory frame 3969
# ()
# Reading trajectory frame 3970
# ()
# Reading trajectory frame 3971
# ()
# Reading trajectory frame 3972
# ()
# Reading trajectory frame 3973
# ()
# Reading trajectory frame 3974
# ()
# Reading trajectory frame 3975
# ()
# Reading trajectory frame 3976
# ()
# Reading trajectory frame 3977
# ()
# Reading trajectory frame 3978
# ()
# Reading trajectory frame 3979
# ()
# Reading trajectory frame 3980
# ()
# Reading trajectory frame 3981
# ()
# Reading trajectory frame 3982
# ()
# Reading trajectory frame 3983
# ()
# Reading trajectory frame 3984
# ()
# Reading trajectory frame 3985
# ()
# Reading trajectory frame 3986
# ()
# Reading trajectory frame 3987
# ()
# Reading trajectory frame 3988
# ()
# Reading trajectory frame 3989
# ()
# Reading trajectory frame 3990
# ()
# Reading trajectory frame 3991
# ()
# Reading trajectory frame 3992
# ()
# Reading trajectory frame 3993
# ()
# Reading trajectory frame 3994
# ()

# %%
lst1 = ("John", "Charles", "Mike")
lst2 = ("Jenny", "Christy", "Monica")

for a, b in zip(lst1, lst2):
    print(a,b)

#use the tuple() function to display a readable version of the result:

print(tuple(x))
# Out:
# John Jenny
# Charles Christy
# Mike Monica
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/p_/mmkyzkc1655_rf8nypyzqx7r0000gn/T/ipykernel_26243/2750364259.py in <module>
#       7 #use the tuple() function to display a readable version of the result:
#       8
# ----> 9 print(tuple(x))
#
# NameError: name 'x' is not defined
